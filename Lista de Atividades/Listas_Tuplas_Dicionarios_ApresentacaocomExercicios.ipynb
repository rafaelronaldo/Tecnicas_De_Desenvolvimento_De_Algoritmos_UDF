# %% [markdown]
# <a href="https://colab.research.google.com/github/rafaelronaldo/Tecnicas_De_Desenvolvimento_De_Algoritmos_UDF/blob/main/Lista%20de%20Atividades/Listas_Tuplas_Dicionarios_ApresentacaocomExercicios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LISTAS E TUPLAS
# São sequências de tipos de dados que armazenam uma coleção ordenada de itens.
#
# **Listas**:
#
# *   mutáveis;
# *   ideias para dados dinâmicos;
# *   homogêneos.
#
# **Tuplas**:
#
#
# *   são imutáveis
# *   ideais para dados fixos (que não serão alterados)
# *   heterogêneos

# %% [markdown]
# # Conceitos - Listas
# É uma estrutra de dados nativa, versátil e amplamente utilizada em Python.
#
# Permite armazenamento e manipulação de uma sequência ordenada e mutável de
# elementos

# %%
colors = ["red", "green", "blue"]
colors[0]
# Out:
# 'red'

# %% [markdown]
# Listas podem conter tipos de dados heterogêneos (string, int, float, object) e suportam
# uma grande quantidade de operações, fazendo com que se tornem essenciais para
# organizar e processar dados.

# %%
lista = ["nome", 32, 1.75]
print(lista)
# Out:
# ['nome', 32, 1.75]

# %% [markdown]
# ## Quando usar listas:
# Armazenar e organizar sequências de dados;
#
# Percorrer elementos;
#
# Adicionar e remover elementos dinamicamente;
#
# Acessar elementos pelo índice;
#
# Ordenar e inverter coleções.

# %%
#retornam um objeto do tipo lista.
lista = list(range(0,10,2))
type (lista)
len(lista)
print(lista)
# Out:
# [0, 2, 4, 6, 8]

# %%
#exemplo de criação de lista

#criando uma lista vazia
empty = []
empty

#criando uma lista a partir de uma tupla
list((1,2,3))
#criando uma lista com elementos
fruits = ["apple", "banana", "cherry"]
fruits
# Out:
# ['apple', 'banana', 'cherry']

# %%
#acessando elementos da lista
fruits[1]
fruits[1:]

#substituindo elementos na lista
fruits[0] = "mango"
fruits

#deletando elementos da lista
del fruits [2]
fruits
# Out:
# ['mango', 'banana']

# %% [markdown]
# ## Métodos de listas
#
# .append() - adiciona um elemento ao fim da lista
#
# .extend() - aumenta a lista acrescentando elementos de um iterável
#
# .insert() - Insere um elemento em uma posição específica
#
# .remove() - Remove a primeira ocorrência do elemento
#
# .pop() - Remove e retorna o elemento de uma posição específica
#
# .clear() - Limpa a lista removendo todos os seus elementos
#
# .index() - Retorna o índice da primeira ocorrência do elemento
#
# .count() - Retorna a quantidade de ocorrências do elemento
#
# .sort() - Ordena a lista
#
# .reverse() - Inverte a lista
#
# .copy() - Cria uma cópia rasa da lista

# %% [markdown]
# # ***TUPLAS***

# %% [markdown]
# Estrutura de dados nativa do Python que entrega uma sequência imutavel de valores.
# Pode guardar qualquer tipo de dado.
# São úteis para armazenar dados heterogênos, como registros de banco de dados ou uma coleção fixa de itens.

# %%
coordinates = (10.5, 20.3)
person = ("Alice", 30, "Enginner")

# %% [markdown]
# É possivel criar truplas: Vazias; Com apenas um item; com múltiplos itens.
#
# Quando criada com apenas um item, a tupla deve ser encerrada com,(vírgula).
#
# Apesar de ser possível criá-las sem parêntesis, convém usa-los a fim de facilitar a legibilidade do código.

# %% [markdown]
# Quando usar listas: Armazenar coleções fixas de dados correlacionados; Retornar múltiplos valores de uma só função; Agrupar dados que não devem mudar com o passar do tempo.

# %% [markdown]
# ## Métodos de tuplas
#
# .index() - Retorna o índice da primeira ocorrência do elemento
#
#
# .count() - Retorna a quantidade de ocorrências do elemento

# %% [markdown]
# # Exercícios

# %% [markdown]
# # TAREFA 1
# Escreva um programa que solicita que o
# usuário digite 5 números inteiros e os coloca
# em uma lista.
#
# Quando terminar, imprima a lista.

# %%
quantidade_numero = []
for contador in range (5):
  numero = int(input("Digite o {}º número: ".format(contador+1)))
  quantidade_numero.append(numero)
print(quantidade_numero)
# Out:
# Digite o 1º número: 5
# Digite o 2º número: 4
# Digite o 3º número: 2
# Digite o 4º número: 3
# Digite o 5º número: 8
# [5, 4, 2, 3, 8]

# %% [markdown]
# # TAREFA 2
#
# Escreva um programa que aplica a função
# módulo a todos os elementos e uma lista.

# %%
lista = [-5, 3, -10, 8, -2]
lista_modulo = []

for numero in lista:
  lista_modulo.append(abs(numero))
print("Lista original: {}".format(lista))
print("Lista em módulo: {}".format(lista_modulo))
# Out:
# Lista original: [-5, 3, -10, 8, -2]
# Lista em módulo: [5, 3, 10, 8, 2]

# %% [markdown]
# # TAREFA 3
# Escreva um programa que apaga todos os
# elementos negativos de uma lista.

# %%
lista = [-5, 3, -10, 8, -2]
lista_sem_negativos = []

for contador in lista:
  if contador >= 0:
    lista_sem_negativos.append(contador)
print(lista_sem_negativos)
# Out:
# [3, 8]

# %% [markdown]
# # TAREFA 4
# Faça um programa que solicita uma
# quantidade indefinida de notas de uma
# prova (deve parar quando um número
# negativo for digitado).

# %%
otas = []
while True:
    n = float(input("Digite a nota (negativo para parar): "))
    if n < 0: break
    notas.append(n)

if len(notas) > 0:
    media = sum(notas) / len(notas)
    print(f"Média das notas: {media:.2f}")
else:
    print("Nenhuma nota informada.")
# Out:
# Digite a nota (negativo para parar): 3
# Digite a nota (negativo para parar): 4
# Digite a nota (negativo para parar): 5
# Digite a nota (negativo para parar): 6
# Digite a nota (negativo para parar): -2
# Média das notas: 5.50

# %% [markdown]
# # TAREFA 5
# Faça um programa que solicita uma
# quantidade indefinida de números positivos
# (deve parar quando um número negativo for
# digitado).
#
# Armazene-os em duas listas:
# uma para os números pares;
# outra para os números ímpares.
#
# A seguir, mostre a porcentagem de pares e
# ímpares digitados.
# Exercícios

# %%
pares = []
impares = []
while True:
    n = int(input("Digite um número positivo (negativo para parar): "))
    if n < 0: break

    if n % 2 == 0:
        pares.append(n)
    else:
        impares.append(n)

total = len(pares) + len(impares)
if total > 0:
    print(f"Pares: {len(pares)} ({(len(pares)/total)*100:.1f}%)")
    print(f"Ímpares: {len(impares)} ({(len(impares)/total)*100:.1f}%)")
# Out:
# Digite um número positivo (negativo para parar): 2
# Digite um número positivo (negativo para parar): 3
# Digite um número positivo (negativo para parar): 4
# Digite um número positivo (negativo para parar): 5
# Digite um número positivo (negativo para parar): 6
# Digite um número positivo (negativo para parar): 7
# Digite um número positivo (negativo para parar): 8
# Digite um número positivo (negativo para parar): 9
# Digite um número positivo (negativo para parar): -1
# Pares: 4 (50.0%)
# Ímpares: 4 (50.0%)

# %% [markdown]
# # TAREFA 6
# Faça um programa que solicita uma
# quantidade indefinida de números positivos
# (deve parar quando um número negativo for
# digitado).
#
# Armazene todos os números digitados em
# uma lista, sem repetição.

# %%
unicos = []
while True:
    n = int(input("Digite número p/ lista única (negativo para parar): "))
    if n < 0: break

    if n not in unicos: # Só adiciona se não existir
        unicos.append(n)
print("Lista sem repetição:", unicos)
# Out:
# Digite número p/ lista única (negativo para parar): 2
# Digite número p/ lista única (negativo para parar): 4
# Digite número p/ lista única (negativo para parar): 6
# Digite número p/ lista única (negativo para parar): 7
# Digite número p/ lista única (negativo para parar): 8
# Digite número p/ lista única (negativo para parar): 9
# Digite número p/ lista única (negativo para parar): 0
# Digite número p/ lista única (negativo para parar): -2
# Lista sem repetição: [2, 4, 6, 7, 8, 9, 0]

# %% [markdown]
# # TAREFA 7
# Escreva um programa que solicita que o
# usuário digite a altura e o peso de 5 pessoas.
# Verifique se pelo menos duas das pessoas
# tem a mesma altura e mesmo peso.

# %%
pessoas = []
duplicado = False

print("\n--- Tarefa 7 ---")
for i in range(5): # Lê 5 pessoas
    alt = float(input(f"Altura da pessoa {i+1}: "))
    peso = float(input(f"Peso da pessoa {i+1}: "))
    dados = (alt, peso) # Cria uma Tupla

    if dados in pessoas: # Verifica se essa combinação já existe
        duplicado = True
    pessoas.append(dados)

if duplicado:
    print("Sim, existem pelo menos duas pessoas com mesmo peso e altura.")
else:
    print("Não há pessoas com medidas idênticas.")
# Out:
# --- Tarefa 7 ---
# Altura da pessoa 1: 1.70
# Peso da pessoa 1: 50
# Altura da pessoa 2: 1.72
# Peso da pessoa 2: 52
# Altura da pessoa 3: 1.73
# Peso da pessoa 3: 54
# Altura da pessoa 4: 1.74
# Peso da pessoa 4: 55
# Altura da pessoa 5: 1.75
# Peso da pessoa 5: 56
# Não há pessoas com medidas idênticas.

# %% [markdown]
# # TAREFA 8

# %% [markdown]
# Faça um programa que solicita que o
# usuário digite o nome e a idade de diversas
# pessoas (o programa deve parar quando
# um nome vazio for informado).
#
# Retorne o nome da pessoa mais velha.

# %%
nome_velho = ""
maior_idade = -1

while True:
    nome = input("Nome (Enter vazio para parar): ")
    if nome == "": break
    idade = int(input("Idade: "))

    if idade > maior_idade:
        maior_idade = idade
        nome_velho = nome

print(f"A pessoa mais velha é: {nome_velho} com {maior_idade} anos.")
# Out:
# Nome (Enter vazio para parar): Angelo
# Idade: 17
# Nome (Enter vazio para parar): Rafael
# Idade: 19
# Nome (Enter vazio para parar):
# A pessoa mais velha é: Rafael com 19 anos.
