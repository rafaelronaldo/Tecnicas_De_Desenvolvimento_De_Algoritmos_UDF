# %% [markdown]
# <a href="https://colab.research.google.com/github/rafaelronaldo/Tecnicas_De_Desenvolvimento_De_Algoritmos/blob/main/Aula2_ADS_RafaelRonaldo_18_09_25_Teste01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nome: Rafael Ronaldo Ferreira Martins
#
# Disciplina: Técnicas de Desenvolvimento de Algoritmos
#
# **Aula: 02**
#
# ![Python-logo (1).png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de tela 2025-09-18 202138.png](data:image/png;base64,...)

# %%
print("Bem vindo!")
advinhacao = int(input("Digite um número:"))
if advinhacao == 5:
  print("Você ganhou!")
else:
  print("Você perdeu!")
  print("Game Over!")
# Out:
# Bem vindo!
# Digite um número:10
# Você perdeu!
# Game Over!
